# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# torch.cuda.device(0)

# %% [markdown]
# ### Tensors

# %%
import numpy as np
arr = np.array([[1,2,3], [4,5,6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
