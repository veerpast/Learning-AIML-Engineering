# %%
"hello" + " world"
# Out:
# 'hello world'

# %%
type(3 + 2.0)
# Out:
# float

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
for x in range(1, 10):
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
1/1 # single / returns float division
# Out:
# 1.0

# %%
1//1
# Out:
# 1

# %%
5//2 # double // returns integer division
# Out:
# 2

# %%
5 % 2 # modulus operator returns remainder of division
# Out:
# 1

# %%
5 ** 4 # exponent operator returns power of a number
# Out:
# 625

# %%
y = "tree"
y
# Out:
# 'tree'

# %%
type(True)
# Out:
# bool

# %%
4 < 3
# Out:
# False

# %%
not True
# Out:
# False

# %%
3.2 > 5
# Out:
# False

# %%
if True:
    print(1)
# Out:
# 1

# %%
x = 7
if x > 7 : 
    print(1)
    print(2)
print(3)
# Out:
# 3

# %%
grocery_list = ["banana", "orange", "apple"]
grocery_list
grocery_list.append("grapes")
grocery_list
# Out:
# ['banana', 'orange', 'apple', 'grapes']

# %%
type(grocery_list)
# Out:
# list

# %%
for item in grocery_list:
    print(item)
# Out:
# banana
# orange
# apple
# grapes

# %%
print(len(grocery_list))
for i in range(4):
    print(grocery_list[i])
# Out:
# 4
# banana
# orange
# apple
# grapes

# %%
list(range(4))
# Out:
# [0, 1, 2, 3]

# %% [markdown]
# ## In Python, enumerate() is a built-in function that lets you loop through a list (or any iterable) while keeping track of both the index (the position number) and the item itself at the same time.

# %%
for i , item in enumerate(grocery_list):
    print(i , item )
# Out:
# 0 banana
# 1 orange
# 2 apple
# 3 grapes

# %%
age = 24
if age > 18:
    print("eligible to vote")
else:
    print("not eligible to vote")    
    
print("hello")
# Out:
# eligible to vote
# hello

# %%
a = ["veer", "veer1", "veer2"]
for idx in range(len(a)):
    print(a[idx])
# Out:
# veer
# veer1
# veer2

# %%
for i in range(1,10):
    if i == 6:
        continue;
    print(i, end = " ")
# Out:
# 1 2 3 4 5 7 8 9

# %%
n = int(input("Enter a number: "))
for i in range(2 , n+1):
    if n % i == 0:
        print(f"divisor {i}")
        break
# Out:
# divisor 3

# %% [markdown]
# ## Functions

# %%
def fun():
    print("We started learning functions")
    
fun()
# Out:
# We started learning functions

# %%
def evenOdd(x):
    if x % 2 ==0:
        return f"{x} is even"
    else:
        return f"{x} is odd"  

n = int(input("Enter a number :"))
print(evenOdd(n))
# Out:
# 12 is even

# %%
def myfun(x, y = 50):
    print("x is ", x)
    print("y is ", y)

myfun(20)
# Out:
# x is  20
# y is  50

# %% [markdown]
# ## *args collects extra positional argumenst as tuple

# %% [markdown]
# ## **kwargs collects extra keyword arguments as a dictionary

# %%
def myfun(*args , **kwargs):
    print("Non keyword arguments:", args)
    for arg in args:
        print(arg)
        
    print("Keyword arguments:", kwargs)
    for key , value in kwargs.items():
        print(f"{key} == {value}")   
        
myfun('Hey', 'welcome', first = 'Geeks', mid = 'for', last = 'Geeks')
# Out:
# Non keyword arguments: ('Hey', 'welcome')
# Hey
# welcome
# Keyword arguments: {'first': 'Geeks', 'mid': 'for', 'last': 'Geeks'}
# first == Geeks
# mid == for
# last == Geeks

# %% [markdown]
# ## Function within functions - nested functions

# %%
def f1():
    s = 'I love Veer'
    def s2():
        print(s)
    s2()
f1()
# Out:
# I love Veer

# %% [markdown]
# ## Recursion In Python

# %%
def factorial(n):
    if n == 0:  # base case
        return 1
    else:
        return n * factorial(n-1) # recursive case
    
factorial(5)
# Out:
# 120
